# %%
import pandas as pd
file = 'mtcars.csv'
df = pd.read_csv(file)
df.head()
# Out:
#                model   mpg  cyl   disp   hp  drat     wt   qsec  vs  am  gear  \
# 0          Mazda RX4  21.0    6  160.0  110  3.90  2.620  16.46   0   1     4
# 1      Mazda RX4 Wag  21.0    6  160.0  110  3.90  2.875  17.02   0   1     4
# 2         Datsun 710  22.8    4  108.0   93  3.85  2.320  18.61   1   1     4
# 3     Hornet 4 Drive  21.4    6  258.0  110  3.08  3.215  19.44   1   0     3
# 4  Hornet Sportabout  18.7    8  360.0  175  3.15  3.440  17.02   0   0     3
#
#    carb
# 0     4
# 1     4
# 2     1
# 3     1
# 4     2

# %%
df.to_csv('mtcars_results1.csv',index = False)

# %%
data = [[1,2,3],
        [1,2,3],
        [1,2,3],
        [1,2,3],
        [4,5,6]]
data
# Out:
# [[1, 2, 3], [1, 2, 3], [1, 2, 3], [1, 2, 3], [4, 5, 6]]

# %%
df = pd.DataFrame(data, columns =["A","B","C"])
df
# Out:
#    A  B  C
# 0  1  2  3
# 1  1  2  3
# 2  1  2  3
# 3  1  2  3
# 4  4  5  6

# %%
data = {"A":[1,2,1,4], "B":[3,4,5,6],"C":[7,8,9,10]}
df = pd.DataFrame(data)
df
# Out:
#    A  B   C
# 0  1  3   7
# 1  2  4   8
# 2  1  5   9
# 3  4  6  10

# %%
data = {"A":[1,2,1,4], "B":[3,4,5,6]}
df1 = pd.DataFrame(data)
df1
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  1  5
# 3  4  6

# %%
data = {"B":[3,4,5,6],"C":[7,8,9,10]}
df2 = pd.DataFrame(data)
df2
# Out:
#    B   C
# 0  3   7
# 1  4   8
# 2  5   9
# 3  6  10

# %%
df3 = pd.merge(df1,df2, on ="B", how = "inner")
df3
# Out:
#    A  B   C
# 0  1  3   7
# 1  2  4   8
# 2  1  5   9
# 3  4  6  10

# %%
df3.sort_values(by = ['A'],ascending=False)
# Out:
#    A  B   C
# 3  4  6  10
# 1  2  4   8
# 0  1  3   7
# 2  1  5   9

# %%
df1
# Out:
#    A  B
# 0  1  3
# 1  2  4
# 2  1  5
# 3  4  6

# %%
df2
# Out:
#    B   C
# 0  3   7
# 1  4   8
# 2  5   9
# 3  6  10

# %%
df4 = pd.concat((df1,df2),axis = 1)
df4
# Out:
#    A  B  B   C
# 0  1  3  3   7
# 1  2  4  4   8
# 2  1  5  5   9
# 3  4  6  6  10

# %%
df5 = pd.concat((df1,df2),axis = 0)
df5 = df5.reset_index()
df5
# Out:
#    index    A  B     C
# 0      0  1.0  3   NaN
# 1      1  2.0  4   NaN
# 2      2  1.0  5   NaN
# 3      3  4.0  6   NaN
# 4      0  NaN  3   7.0
# 5      1  NaN  4   8.0
# 6      2  NaN  5   9.0
# 7      3  NaN  6  10.0

# %%
df3
# Out:
#    A  B   C
# 0  1  3   7
# 1  2  4   8
# 2  1  5   9
# 3  4  6  10

# %%
df3 = df3.rename(columns={"A":'1',"B":'2','C':'3'})
# Out:
#    1  2   3
# 0  1  3   7
# 1  2  4   8
# 2  1  5   9
# 3  4  6  10

# %%
df3
# Out:
#    A  B   C
# 0  1  3   7
# 1  2  4   8
# 2  1  5   9
# 3  4  6  10

# %%
columns_ = ["1","2","3"]
df3.columns = columns_
df3
# Out:
#    1  2   3
# 0  1  3   7
# 1  2  4   8
# 2  1  5   9
# 3  4  6  10

# %%
df3['4'] = df3['2']+df3['3']
df3
# Out:
#    1  2   3   4
# 0  1  3   7  10
# 1  2  4   8  12
# 2  1  5   9  14
# 3  4  6  10  16

# %%
df3[df3['4']>12]
# Out:
#    1  2   3   4
# 2  1  5   9  14
# 3  4  6  10  16

# %%
df3[df3['4'].isin([10,16])]
# Out:
#    1  2   3   4
# 0  1  3   7  10
# 3  4  6  10  16

# %%
df3 = df3.drop(columns = ['4'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# c:\Users\vara\vscode\youtube\pandas.ipynb Cell 21' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/vara/vscode/youtube/pandas.ipynb#ch0000024?line=0'>1</a> df3 = df3.drop(columns = ['4'])
#
# File c:\Users\vara\Documents\Zoom\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# File c:\Users\vara\Documents\Zoom\lib\site-packages\pandas\core\frame.py:4954, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df3
# Out:
#    1  2   3
# 0  1  3   7
# 1  2  4   8
# 2  1  5   9
# 3  4  6  10

# %%
df3.groupby(['1'])['2'].sum()
# Out:
# 1
# 1    8
# 2    4
# 4    6
# Name: 2, dtype: int64

# %%
df3['2'].unique()
# Out:
# array([3, 4, 5, 6], dtype=int64)

# %%
df5
# Out:
#    index    A  B     C
# 0      0  1.0  3   NaN
# 1      1  2.0  4   NaN
# 2      2  1.0  5   NaN
# 3      3  4.0  6   NaN
# 4      0  NaN  3   7.0
# 5      1  NaN  4   8.0
# 6      2  NaN  5   9.0
# 7      3  NaN  6  10.0

# %%
df5['A'].fillna(0,inplace=True)
df5
# Out:
#    index    A  B     C
# 0      0  1.0  3   NaN
# 1      1  2.0  4   NaN
# 2      2  1.0  5   NaN
# 3      3  4.0  6   NaN
# 4      0  0.0  3   7.0
# 5      1  0.0  4   8.0
# 6      2  0.0  5   9.0
# 7      3  0.0  6  10.0

# %%
df5['C'].fillna('A',inplace=True)
df5
# Out:
#    index    A  B     C
# 0      0  1.0  3     A
# 1      1  2.0  4     A
# 2      2  1.0  5     A
# 3      3  4.0  6     A
# 4      0  0.0  3   7.0
# 5      1  0.0  4   8.0
# 6      2  0.0  5   9.0
# 7      3  0.0  6  10.0

# %%
def f(number):
    return number + 1

df5['D'] = df5['B'].apply(f)
df5
# Out:
#    index    A  B     C  D
# 0      0  1.0  3     A  4
# 1      1  2.0  4     A  5
# 2      2  1.0  5     A  6
# 3      3  4.0  6     A  7
# 4      0  0.0  3   7.0  4
# 5      1  0.0  4   8.0  5
# 6      2  0.0  5   9.0  6
# 7      3  0.0  6  10.0  7

# %%
df5.drop_duplicates()
# Out:
#    index    A  B     C  D
# 0      0  1.0  3     A  4
# 1      1  2.0  4     A  5
# 2      2  1.0  5     A  6
# 3      3  4.0  6     A  7
# 4      0  0.0  3   7.0  4
# 5      1  0.0  4   8.0  5
# 6      2  0.0  5   9.0  6
# 7      3  0.0  6  10.0  7

# %%
df6 = pd.DataFrame([[1,"A"],
                    [1,"A"],
                    [2,"A"],
                    [2,"A"]],)
df6
# Out:
#    0  1
# 0  1  A
# 1  1  A
# 2  2  A
# 3  2  A

# %%
df6 = df6.drop_duplicates()
df6
# Out:
#    0  1
# 0  1  A
# 2  2  A

# %%
df6[1].value_counts()
# Out:
# A    2
# Name: 1, dtype: int64

# %%
df6.shape
# Out:
# (2, 2)

# %%
df5.shape
# Out:
# (8, 5)
